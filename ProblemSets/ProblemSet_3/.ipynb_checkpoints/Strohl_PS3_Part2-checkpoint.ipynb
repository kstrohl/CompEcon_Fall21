# %% [markdown]
# ### Kaleigh Strohl | Problem Set 3: Data Visualizations, Part 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
msudata2 = pd.read_excel('nassar_full.xlsx', header=0, index_col=None)
msudata2.head(n=10)
# Out:
#     num  UnitID                            college  college_id  year  \
# 0  1522  123961  University of Southern California           1  2019
# 1  1523  123961  University of Southern California           1  2018
# 2  1524  123961  University of Southern California           1  2017
# 3  1525  123961  University of Southern California           1  2016
# 4  1526  123961  University of Southern California           1  2015
# 5  1527  123961  University of Southern California           1  2014
# 6  1528  123961  University of Southern California           1  2013
# 7  1529  123961  University of Southern California           1  2012
# 8  1530  123961  University of Southern California           1  2011
# 9  1531  123961  University of Southern California           1  2010
#
#    division  power_ball  SAT_read25  SAT_read75  SAT_math25  ...  hispanic  \
# 0         1           1       670.0       740.0       690.0  ...    3124.0
# 1         1           1       660.0       740.0       690.0  ...    2990.0
# 2         1           1       650.0       730.0       650.0  ...    2743.0
# 3         1           1       630.0       730.0       650.0  ...    2603.0
# 4         1           1       620.0       730.0       650.0  ...    2564.0
# 5         1           1       620.0       720.0       660.0  ...    2516.0
# 6         1           1       620.0       720.0       660.0  ...    2480.0
# 7         1           1       620.0       720.0       650.0  ...    2522.0
# 8         1           1       610.0       720.0       670.0  ...    2415.0
# 9         1           1       620.0       720.0       650.0  ...    2372.0
#
#    native_hawaiian   white  multiracial  ethn_unknown  nonresident_alien  \
# 0             53.0  7511.0       1205.0         443.0             2705.0
# 1             47.0  7699.0       1139.0         297.0             2664.0
# 2             46.0  7527.0       1073.0         316.0             2674.0
# 3             42.0  7403.0        987.0         359.0             2669.0
# 4             30.0  7451.0        967.0         313.0             2676.0
# 5             32.0  6706.0        935.0        1020.0             2551.0
# 6             21.0  6899.0        863.0         841.0             2335.0
# 7             31.0  7213.0        810.0         500.0             2237.0
# 8             31.0  7114.0        770.0         181.0             2137.0
# 9             41.0  7467.0        764.0         228.0             1955.0
#
#    undergrad_total  men_total  women_total  retention_rate
# 0            20351       9849        10502            96.0
# 1            19907       9724        10183            97.0
# 2            19170       9296         9874            96.0
# 3            18794       9076         9718            96.0
# 4            18810       9308         9502            96.0
# 5            18739       9285         9454            97.0
# 6            18445       9157         9288            96.0
# 7            18316       9032         9284            97.0
# 8            17414       8606         8808            97.0
# 9            17380       8602         8778            97.0
#
# [10 rows x 39 columns]

# %%
applications  = msudata2.sort_values(by=["year", "total_apps", "college"])[["year", "total_apps", "college"]]
applications
# Out:
#       year  total_apps                                    college
# 1177  2001       912.0             Centenary College of Louisiana
# 1937  2001      1234.0                   Texas Woman's University
# 911   2001      1355.0                   University of Bridgeport
# 1386  2001      1461.0                         Hamline University
# 1861  2001      1562.0                            Ursinus College
# ...    ...         ...                                        ...
# 0     2019     66198.0          University of Southern California
# 798   2019     78093.0             University of California-Davis
# 779   2019     87847.0          University of California-Berkeley
# 1767  2019     95970.0  Pennsylvania State University-Main Campus
# 817   2019    111321.0       University of California-Los Angeles
#
# [2166 rows x 3 columns]

# %%
table = applications[-10:]
table
# Out:
#       year  total_apps                                    college
# 1539  2019     49114.0                         Cornell University
# 494   2019     53525.0          The University of Texas at Austin
# 627   2019     55311.0              Purdue University-Main Campus
# 38    2019     58936.0                   Florida State University
# 1292  2019     64972.0           University of Michigan-Ann Arbor
# 0     2019     66198.0          University of Southern California
# 798   2019     78093.0             University of California-Davis
# 779   2019     87847.0          University of California-Berkeley
# 1767  2019     95970.0  Pennsylvania State University-Main Campus
# 817   2019    111321.0       University of California-Los Angeles

# %%
y = table.total_apps
x = table.college

fig, ax = plt.subplots()
plt.barh(x, y)
plt.xlabel("Number of Applications")
plt.title("Colleges with Highest Number of Applications in 2019")
plt.savefig('college_apps2.png', transparent=False, dpi=800, bbox_inches="tight")
plt.show()
